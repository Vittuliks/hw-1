# %%
import os
print("Папка:", os.getcwd())
print("Файлы:", os.listdir())
# Out:
# Папка: C:\ImageProcessing\hw-1
# Файлы: ['.ipynb_checkpoints', 'homework.ipynb', 'sar_1_gray.jpg', 'sar_2_color.jpg']
